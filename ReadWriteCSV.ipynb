# %% [markdown]
# <a href="https://colab.research.google.com/github/LuciferAsh98/AI-ML-Learning-Path/blob/main/ReadWriteCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("ransomware_extensions.csv")
df.head(10)
# Out:
#    Extensions              Name
# 0        .enc    .CryptoHasYou.
# 1        .777               777
# 2        .R4A             7ev3n
# 3        .R5A             7ev3n
# 4       .7h9r              7h9r
# 5     .8lock8            8lock8
# 6    .encrypt  Alpha Ransomware
# 7       .amba              AMBA
# 8        .adk        Angry Duck
# 9  .encrypted        Apocalypse
# No charts were generated by quickchart

# %%
new_row = pd.DataFrame([{'Extensions': '.test', 'Name': 'Test Ransomware'}])

df = pd.concat([df, new_row], ignore_index=True)

# %%
print(df.tail(10))
# Out:
#     Extensions              Name
# 239    .zcrypt            Zcrypt
# 240    .crypto            Zimbra
# 241     .vault  Zlader / Russian
# 242    .zyklon            Zyklon
# 243     .wncry          WannaCry
# 244      .wcry          WannaCry
# 245      .wnry          WannaCry
# 246    .wncryt          WannaCry
# 247    .WNCRYT          WannaCry
# 248      .test   Test Ransomware
